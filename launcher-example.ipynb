# %%
import project

# %%
# Enter the desired title for the graph as 'graph_title'
title = 'F1'
# Enter the names of the 20 Excel files you want to consider in the analysis as 'name_of_file.xlsx'
filename0 = 'data/HT400-15min-F1-1.xlsx'
filename1 = 'data/HT400-15min-F1-2.xlsx'
filename2 = 'data/HT400-15min-F1-3.xlsx'

filename3 = 'data/HT450-15min-F1-1.xlsx'
filename4 = 'data/HT450-15min-F1-2.xlsx'
filename5 = 'data/HT450-15min-F1-3.xlsx'

filename6 = 'data/NoHT-F1-1.xlsx'
filename7 = 'data/NoHT-F1-2.xlsx'
filename8 = 'data/NoHT-F1-3.xlsx'

filename9 = 'data/HT400-45min-F1-1.xlsx'
filename10 = 'data/HT400-45min-F1-2.xlsx'
filename11 = 'data/HT400-45min-F1-3.xlsx'

filename12 = 'data/HT450-45min-F1-1.xlsx'
filename13 = 'data/HT450-45min-F1-2.xlsx'
filename14 = 'data/HT450-45min-F1-3.xlsx'

filename15 = 'data/B1-1.xlsx'
filename16 = 'data/B1-2.xlsx'
filename17 = 'data/B1-3.xlsx'

filename18 = 'data/PG-F1-1.xlsx'
filename19 = 'data/PG-F1-2.xlsx'
filename20 = 'data/PG-F1-3.xlsx'

# %%
project.graph(title,
              filename0, filename1, filename2,
              filename3, filename4, filename5,
              filename6, filename7, filename8,
              filename9, filename10, filename11,
              filename12, filename13, filename14,
              filename15, filename16, filename17,
              filename18, filename19, filename20)

# %%
project.mean(filename0, filename1, filename2)

# %%
project.std(filename0, filename1, filename2)
